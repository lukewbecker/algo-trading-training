# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import math
import datetime

# %%
import env
# Out:
# Polygon.io API key loaded up.
# Cboe API key loaded up.
# TD Ameritrade API key loaded up.
# Coinbase API key loaded up.
# All credentials loaded successfully

# %%
# Will need the requests library in order to use the RESTful json API Coinbase provides.

import requests

# %%
response_time_test = requests.get('https://api.coinbase.com/v2/time')
response_time_test
# Out:
# <Response [200]>

# %%
import json

# %%
from models.CoinbaseProAPI import CoinbaseProAPI

# %% [markdown]
# ## Using Coinbase Library for API calls
#
# - Using the CoinbasePro API library available from this GitHub respository: https://github.com/danpaquin/coinbasepro-python

# %%
import cbpro

# %%
public_client = cbpro.PublicClient()

# %%
public_client.get_products()
# Out:
# [{'id': 'BAL-USD',
#   'base_currency': 'BAL',
#   'quote_currency': 'USD',
#   'base_min_size': '0.10000000',
#   'base_max_size': '6700.00000000',
#   'quote_increment': '0.00001000',
#   'base_increment': '0.00100000',
#   'display_name': 'BAL/USD',
#   'min_market_funds': '1.0',
#   'max_market_funds': '100000',
#   'margin_enabled': False,
#   'post_only': False,
#   'limit_only': False,
#   'cancel_only': False,
#   'trading_disabled': False,
#   'status': 'online',
#   'status_message': ''},
#  {'id': 'ZEC-BTC',
#   'base_currency': 'ZEC',
#   'quote_currency': 'BTC',
#   'base_min_size': '0.01000000',
#   'base_max_size': '1500.00000000',
#   'quote_increment': '0.00000100',
#   'base_increment': '0.00010000',
#   'display_name': 'ZEC/BTC',
#   'min_market_funds': '0.001',
#   'max_market_funds': '30',
#   'margin_enabled': False,
#   'post_only': False,
#   'limit_only': False,
#   'cancel_only': False,
#   'trading_disabled': False,
#   'status': 'online',
# ...

# %%
public_client.get_time()
# Out:
# {'iso': '2021-02-09T16:24:21.443Z', 'epoch': 1612887861.443}

# %%
public_client.get_currencies()
# Out:
# [{'id': 'ALGO',
#   'name': 'Algorand',
#   'min_size': '1',
#   'status': 'online',
#   'message': '',
#   'max_precision': '0.000001',
#   'convertible_to': [],
#   'details': {'type': 'crypto',
#    'symbol': 'A',
#    'network_confirmations': 1,
#    'sort_order': 93,
#    'crypto_address_link': 'https://algoexplorer.io/address/{{address}}',
#    'crypto_transaction_link': 'https://algoexplorer.io/tx/{{txId}}',
#    'push_payment_methods': ['crypto'],
#    'group_types': [],
#    'display_name': '',
#    'processing_time_seconds': 5,
#    'min_withdrawal_amount': 0.1,
#    'max_withdrawal_amount': 1000000}},
#  {'id': 'DASH',
#   'name': 'Dash',
#   'min_size': '1',
#   'status': 'online',
#   'message': '',
#   'max_precision': '0.00000001',
#   'convertible_to': [],
#   'details': {'type': 'crypto',
#    'symbol': '',
#    'network_confirmations': 2,
#    'sort_order': 47,
#    'crypto_address_link': 'https://chain.so/address/DASH/{{address}}',
# ...

# %%
test = public_client.get_currencies()

# %%
type(test)
# Out:
# list

# %%
pd.DataFrame(test)
# Out:
#       id                   name    min_size  status  \
# 0   ALGO               Algorand           1  online
# 1   DASH                   Dash           1  online
# 2    OXT                 Orchid           1  online
# 3   ATOM                 Cosmos           1  online
# 4    KNC          Kyber Network           1  online
# 5    XRP                    XRP           1  online
# 6    REP                  Augur    0.000001  online
# 7    MKR                  Maker       0.001  online
# 8   CGLD                   Celo         0.1  online
# 9   COMP               Compound        0.01  online
# 10   NMR              Numeraire        0.01  online
# 11   OMG            OMG Network           1  online
# 12  BAND          Band Protocol         0.1  online
# 13   UMA                    UMA        0.01  online
# 14   XLM                Stellar           1  online
# 15   EOS                    EOS         0.1  online
# 16   ZRX                     0x     0.00001  online
# ...

# %%
df = pd.DataFrame(test)
df
# Out:
#       id                   name    min_size  status  \
# 0   ALGO               Algorand           1  online
# 1   DASH                   Dash           1  online
# 2    OXT                 Orchid           1  online
# 3   ATOM                 Cosmos           1  online
# 4    KNC          Kyber Network           1  online
# 5    XRP                    XRP           1  online
# 6    REP                  Augur    0.000001  online
# 7    MKR                  Maker       0.001  online
# 8   CGLD                   Celo         0.1  online
# 9   COMP               Compound        0.01  online
# 10   NMR              Numeraire        0.01  online
# 11   OMG            OMG Network           1  online
# 12  BAND          Band Protocol         0.1  online
# 13   UMA                    UMA        0.01  online
# 14   XLM                Stellar           1  online
# 15   EOS                    EOS         0.1  online
# 16   ZRX                     0x     0.00001  online
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              48 non-null     object
#  1   name            48 non-null     object
#  2   min_size        48 non-null     object
#  3   status          48 non-null     object
#  4   message         48 non-null     object
#  5   max_precision   48 non-null     object
#  6   convertible_to  48 non-null     object
#  7   details         48 non-null     object
# dtypes: object(8)
# memory usage: 3.1+ KB

# %%
df.shape
# Out:
# (48, 8)

# %%
df.name.describe()
# Out:
# count         48
# unique        48
# top       Cosmos
# freq           1
# Name: name, dtype: object

# %%
import json
from CoinbaseProAPI import CoinbaseProAPI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-d0a0c6b79d31> in <module>
#       1 import json
# ----> 2 from models.CoinbaseProAPI import CoinbaseProAPI
#
# ModuleNotFoundError: No module named 'models.CoinbaseProAPI'
