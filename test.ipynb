# %%
import cbpro

# %%
public_client = cbpro.PublicClient()

# %%
public_client.get_products()
# Out:
# [{'id': 'BNT-EUR',
#   'base_currency': 'BNT',
#   'quote_currency': 'EUR',
#   'base_min_size': '1.00000000',
#   'base_max_size': '95000.00000000',
#   'quote_increment': '0.00010000',
#   'base_increment': '0.00000100',
#   'display_name': 'BNT/EUR',
#   'min_market_funds': '1.0',
#   'max_market_funds': '92000',
#   'margin_enabled': False,
#   'post_only': False,
#   'limit_only': False,
#   'cancel_only': False,
#   'trading_disabled': False,
#   'status': 'online',
#   'status_message': ''},
#  {'id': 'NU-BTC',
#   'base_currency': 'NU',
#   'quote_currency': 'BTC',
#   'base_min_size': '10.00000000',
#   'base_max_size': '1300000.00000000',
#   'quote_increment': '0.00000001',
#   'base_increment': '1.00000000',
#   'display_name': 'NU/BTC',
#   'min_market_funds': '0.0001',
#   'max_market_funds': '6',
#   'margin_enabled': False,
#   'post_only': False,
#   'limit_only': False,
#   'cancel_only': False,
#   'trading_disabled': False,
#   'status': 'online',
# ...

# %%
import pandas as pd

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : 67a3d4241ab84419856b84fc3ebc9abcbe66c6b3
# python           : 3.7.9.final.0
# python-bits      : 64
# OS               : Darwin
# OS-release       : 20.3.0
# Version          : Darwin Kernel Version 20.3.0: Thu Jan 21 00:07:06 PST 2021; root:xnu-7195.81.3~1/RELEASE_X86_64
# machine          : x86_64
# processor        : i386
# byteorder        : little
# LC_ALL           : None
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.1.4
# numpy            : 1.18.5
# pytz             : 2020.5
# dateutil         : 2.8.1
# pip              : 20.3.3
# setuptools       : 51.3.3.post20210118
# Cython           : 0.29.21
# pytest           : 6.2.1
# hypothesis       : 6.0.3
# sphinx           : 3.4.3
# blosc            : None
# feather          : None
# xlsxwriter       : 1.3.7
# lxml.etree       : 4.6.2
# html5lib         : 1.1
# pymysql          : 0.10.0
# psycopg2         : None
# ...

# %%
python.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-45a3ce2a2cc7> in <module>
# ----> 1 python.__version__
#
# NameError: name 'python' is not defined
