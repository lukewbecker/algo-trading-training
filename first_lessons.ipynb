# %%
# Running this because somehow using jedi in my notebook is taking a really long time

# %config Completer.use_jedi = False

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import datetime

# from datetime import datetime
# from datetime import timedelta
# import re

# from fbprophet import Prophet
# from sklearn.metrics import mean_squared_error

# import PySimpleGUI as sg

# %%
import yfinance as yf

# %%
yf.download
# Out:
# <function yfinance.multi.download(tickers, start=None, end=None, actions=False, threads=True, group_by='column', auto_adjust=False, back_adjust=False, progress=True, period='max', interval='1d', prepost=False, proxy=None, rounding=False, **kwargs)>

# %%
yf.download("MSFT", start = "2020-01-01", end = "2021-01-25", interval = '60m')
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2020-01-02 09:30:00-05:00  158.779999  159.554993  158.330002  159.100006
# 2020-01-02 10:30:00-05:00  159.095001  159.630005  158.990005  159.485001
# 2020-01-02 11:30:00-05:00  159.479996  159.619995  159.110001  159.529999
# 2020-01-02 12:30:00-05:00  159.520004  159.800003  159.445007  159.615005
# 2020-01-02 13:30:00-05:00  159.615005  159.949997  159.529999  159.934998
# ...                               ...         ...         ...         ...
# 2021-01-22 11:30:00-05:00  228.520004  228.539993  227.580002  228.279999
# 2021-01-22 12:30:00-05:00  228.289993  228.309998  227.169998  227.460007
# 2021-01-22 13:30:00-05:00  227.470001  227.639999  227.100006  227.500000
# 2021-01-22 14:30:00-05:00  227.505707  227.559998  226.532501  226.684998
# 2021-01-22 15:30:00-05:00  226.690002  227.199997  225.800003  225.839996
#
# ...

# %%
yf.download("MSFT", period = '1mo', interval = '5m')
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2020-12-28 09:30:00-05:00  224.449997  224.550003  223.589996  223.684998
# 2020-12-28 09:35:00-05:00  224.039993  224.089996  223.610001  223.881607
# 2020-12-28 09:40:00-05:00  223.919998  223.960007  223.589996  223.646896
# 2020-12-28 09:45:00-05:00  223.375000  223.679993  223.360397  223.574402
# 2020-12-28 09:50:00-05:00  223.449997  223.800003  223.149994  223.789993
# ...                               ...         ...         ...         ...
# 2021-01-26 11:10:00-05:00  232.369995  232.669998  231.750000  231.750000
# 2021-01-26 11:15:00-05:00  231.750000  232.429993  231.710007  232.335999
# 2021-01-26 11:20:00-05:00  232.330002  232.567902  231.970001  232.000000
# 2021-01-26 11:25:00-05:00  232.009995  232.029999  231.630005  231.820007
# 2021-01-26 11:28:58-05:00  231.770004  231.770004  231.770004  231.770004
#
# ...

# %%
# Lesson 2

# %%
stocks = ['AMZN', "MSFT", "INTC", "GME", "TSLA", "AAPL"]
start = datetime.datetime.today() - datetime.timedelta(30)
end = datetime.datetime.today()
cl_price = pd.DataFrame()
ohlcv_data = {}

for ticker in stocks:
    cl_price[ticker] = yf.download(ticker, start, end)['Adj Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
cl_price
# Out:
#                    AMZN        MSFT       INTC        GME        TSLA  \
# Date
# 2020-12-28  3283.959961  224.960007  47.070000  20.990000  663.690002
# 2020-12-29  3322.000000  224.149994  49.389999  19.379999  665.989990
# 2020-12-30  3285.850098  221.679993  48.750000  19.260000  694.780029
# 2020-12-31  3256.929932  222.419998  49.820000  18.840000  705.669983
# 2021-01-04  3186.629883  217.690002  49.669998  17.250000  729.770020
# 2021-01-05  3218.510010  217.899994  50.610001  17.370001  735.109985
# 2021-01-06  3138.379883  212.250000  51.099998  18.360001  755.979980
# 2021-01-07  3162.159912  218.289993  52.189999  18.080000  816.039978
# 2021-01-08  3182.699951  219.619995  51.650002  17.690001  880.020020
# 2021-01-11  3114.209961  217.490005  51.540001  19.940001  811.190002
# 2021-01-12  3120.830078  214.929993  53.240002  19.950001  849.440002
# 2021-01-13  3165.889893  216.339996  56.950001  31.400000  854.409973
# ...

# %%
cl_price[cl_price.isnull()].shape
# Out:
# (20, 6)

# %%
stocks = ['AMZN', "MSFT", "INTC", "GME", "TSLA", "AAPL"]
start = datetime.datetime.today() - datetime.timedelta(30)
end = datetime.datetime.today()
cl_price = pd.DataFrame()
ohlcv_data = {}

for ticker in stocks:
    cl_price[ticker] = yf.download(ticker, start, end)['Adj Close']
    
for ticker in stocks:
    ohlcv_data[ticker] = yf.download(ticker, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
ohlcv_data["MSFT"]["Open"]
# Out:
# Date
# 2020-12-28    224.449997
# 2020-12-29    226.309998
# 2020-12-30    225.229996
# 2020-12-31    221.699997
# 2021-01-04    222.529999
# 2021-01-05    217.259995
# 2021-01-06    212.169998
# 2021-01-07    214.039993
# 2021-01-08    218.679993
# 2021-01-11    218.470001
# 2021-01-12    216.500000
# 2021-01-13    214.020004
# 2021-01-14    215.910004
# 2021-01-15    213.520004
# 2021-01-19    213.750000
# 2021-01-20    217.699997
# 2021-01-21    224.699997
# 2021-01-22    227.080002
# 2021-01-25    229.119995
# 2021-01-26    231.860001
# Name: Open, dtype: float64

# %%
from yahoofinancials import YahooFinancials

# %%
ticker_test = "MSFT"
yahoo_financials = YahooFinancials(ticker)
data_test = yahoo_financials.get_historical_price_data("2019-12-31", "2021-01-25", "daily")

# %%
data_test
# Out:
# {'AAPL': {'eventsData': {'dividends': {'2020-02-07': {'amount': 0.1925,
#      'date': 1581085800,
#      'formatted_date': '2020-02-07'},
#     '2020-05-08': {'amount': 0.205,
#      'date': 1588944600,
#      'formatted_date': '2020-05-08'},
#     '2020-08-07': {'amount': 0.205,
#      'date': 1596807000,
#      'formatted_date': '2020-08-07'},
#     '2020-11-06': {'amount': 0.205,
#      'date': 1604673000,
#      'formatted_date': '2020-11-06'}},
#    'splits': {'2020-08-31': {'date': 1598880600,
#      'numerator': 4,
#      'denominator': 1,
#      'splitRatio': '4:1',
#      'formatted_date': '2020-08-31'}}},
#   'firstTradeDate': {'formatted_date': '1980-12-12', 'date': 345479400},
#   'currency': 'USD',
#   'instrumentType': 'EQUITY',
#   'timeZone': {'gmtOffset': -18000},
#   'prices': [{'date': 1577802600,
#     'high': 73.41999816894531,
#     'low': 72.37999725341797,
#     'open': 72.48249816894531,
#     'close': 73.4124984741211,
#     'volume': 100805600,
# ...
